# %%
import pandas

# %%
from patsy import dmatrices

# %%
import statsmodels.api as sm

# %%
fertility = sm.datasets.fertility.load_pandas()['data']; # Loading dataset

# %%
vars = ['Country Name', '2001', '2002', '2003']

# %%
trial = fertility[vars]

# %%
fertility.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
# 1986              float64
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
fertility_transpose = fertility.transpose() #Transposing to make countries the column and the year data continuous

# %%
almostfinal = fertility_transpose.drop(['Indicator Name', 'Indicator Code'], axis = 0) 
# Getting rid of indicator name and code as it is irrelevant

# %%
final.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3      object
# 4      object
#         ...
# 214    object
# 215    object
# 216    object
# 217    object
# 218    object
# Length: 219, dtype: object

# %%
almostfinal.columns = final.iloc[0] # Making country name the column heading for dataset

# %%
almostfinal = almostfinal.drop(['Country Code'], axis = 0) # Discarding country code row

# %%
final = almostfinal.drop(almostfinal.index[0]) # Dropping duplicate of country name row

# %%
final = final.astype(float) # Change data type from object to float

# %%
final.dtypes
# Out:
# Country Name
# Aruba               float64
# Andorra             float64
# Afghanistan         float64
# Angola              float64
# Albania             float64
#                      ...
# Yemen, Rep.         float64
# South Africa        float64
# Congo, Dem. Rep.    float64
# Zambia              float64
# Zimbabwe            float64
# Length: 219, dtype: object

# %%
final.plot() # Plot of every data point within dataset
# Out:
# <AxesSubplot:>

# %%
final["United States"].plot() # Checking that plots work with individual countries
# Out:
# <AxesSubplot:>
